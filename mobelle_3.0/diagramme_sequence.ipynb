# %% [markdown]
# Diagramme de séquence pour administrateur

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Créer une nouvelle figure et un axe
fig, ax = plt.subplots(figsize=(12, 12))

# Définir les limites de l'axe et le titre
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
ax.set_title("Diagramme de Séquence pour l'Administrateur", fontsize=16)

# Fonction pour ajouter des lifelines avec le texte en haut
def add_lifeline(x, y_start, y_end, label, color, lw=2):
    ax.plot([x, x], [y_start, y_end], color=color, lw=lw)
    ax.text(x, y_end + 2, label, fontsize=12, ha='center', va='bottom', bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=color))

# Fonction pour ajouter des messages
def add_message(x_start, x_end, y, message, direction='->'):
    if direction == '->':
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="->", lw=1.5, color='blue'),
                    fontsize=10, ha='center', va='center', color='blue')
    else:
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="<-", lw=1.5, color='green'),
                    fontsize=10, ha='center', va='center', color='green')

# Ajouter des lifelines avec plus d'espace
add_lifeline(10, 10, 90, 'Administrateur', 'red', lw=1)
add_lifeline(50, 10, 90, 'Système', 'grey', lw=1)
add_lifeline(90, 10, 90, 'Base de Données', 'green', lw=1)

# Ajouter des messages avec plus d'espacement
y_pos = 85
step = 4.5

# Se connecter
add_message(10, 50, y_pos, 'Se Connecter')
y_pos -= step
add_message(50, 10, y_pos, 'Confirmer Identifiants', direction='<-')
y_pos -= step
add_message(50, 90, y_pos, 'Vérifier Identifiants')
y_pos -= step
add_message(90, 50, y_pos, 'Résultat de la Vérification', direction='<-')
y_pos -= step
add_message(50, 10, y_pos, 'Accès Accordé', direction='<-')

# Ajouter Personnel
y_pos -= step
add_message(10, 50, y_pos, 'Ajouter Personnel')
y_pos -= step
add_message(50, 90, y_pos, 'Enregistrer Personnel')
y_pos -= step
add_message(90, 50, y_pos, 'Confirmation d\'ajout Personnel', direction='<-')


# Ajouter Poubelle
y_pos -= step
add_message(10, 50, y_pos, 'Ajouter Poubelle')
y_pos -= step
add_message(50, 90, y_pos, 'Enregistrer Poubelle')
y_pos -= step
add_message(90, 50, y_pos, 'Confirmation d\'ajout', direction='<-')

# Voir les Poubelles
y_pos -= step
add_message(10, 50, y_pos, 'Voir les Poubelles')
y_pos -= step
add_message(50, 90, y_pos, 'Récupérer Données Poubelles')
y_pos -= step
add_message(90, 50, y_pos, 'Données Poubelles', direction='<-')

# Voir Carte
y_pos -= step
add_message(10, 50, y_pos, 'Voir Carte')
y_pos -= step
add_message(50, 90, y_pos, 'Afficher Carte')
y_pos -= step
add_message(90, 50, y_pos, 'Carte Affichée', direction='<-')

# Masquer les axes
ax.axis('off')

# Afficher le diagramme
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Diagramme de séquence pour Personnel

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Créer une nouvelle figure et un axe
fig, ax = plt.subplots(figsize=(12, 12))

# Définir les limites de l'axe et le titre
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
ax.set_title("Diagramme de Séquence pour le Personnel", fontsize=16)

# Fonction pour ajouter des lifelines avec le texte en haut
def add_lifeline(x, y_start, y_end, label, color, lw=2):
    ax.plot([x, x], [y_start, y_end], color=color, lw=lw)
    ax.text(x, y_end + 2, label, fontsize=12, ha='center', va='bottom', bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=color))

# Fonction pour ajouter des messages
def add_message(x_start, x_end, y, message, direction='->'):
    if direction == '->':
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="->", lw=1.5, color='blue'),
                    fontsize=10, ha='center', va='center', color='blue')
    else:
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="<-", lw=1.5, color='green'),
                    fontsize=10, ha='center', va='center', color='green')

# Ajouter des lifelines avec plus d'espace
add_lifeline(10, 10, 90, 'Personnel', 'red', lw=1)
add_lifeline(50, 10, 90, 'Système', 'grey', lw=1)
add_lifeline(90, 10, 90, 'Base de Données', 'green', lw=1)

# Ajouter des messages avec plus d'espacement
y_pos = 85
step = 5.5

# Se connecter
add_message(10, 50, y_pos, 'Se Connecter')
y_pos -= step
add_message(50, 10, y_pos, 'Confirmer Identifiants', direction='<-')
y_pos -= step
add_message(50, 90, y_pos, 'Vérifier Identifiants')
y_pos -= step
add_message(90, 50, y_pos, 'Résultat de la Vérification', direction='<-')
y_pos -= step
add_message(50, 10, y_pos, 'Accès Accordé', direction='<-')

# Voir les Poubelles
y_pos -= step
add_message(10, 50, y_pos, 'Voir les Poubelles')
y_pos -= step
add_message(50, 90, y_pos, 'Récupérer Données Poubelles')
y_pos -= step
add_message(90, 50, y_pos, 'Données Poubelles', direction='<-')

# Voir les Poubelles à Vider
y_pos -= step
add_message(10, 50, y_pos, 'Voir les Poubelles à Vider')
y_pos -= step
add_message(50, 90, y_pos, 'Récupérer Données Poubelles à Vider')
y_pos -= step
add_message(90, 50, y_pos, 'Données Poubelles à Vider', direction='<-')

# Voir Carte
y_pos -= step
add_message(10, 50, y_pos, 'Voir Carte')
y_pos -= step
add_message(50, 90, y_pos, 'Afficher Carte')
y_pos -= step
add_message(90, 50, y_pos, 'Carte Affichée', direction='<-')

# Masquer les axes
ax.axis('off')

# Afficher le diagramme
plt.show()

# %% [markdown]
# Diagramme de Séquence pour l'Utilisateur

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Créer une nouvelle figure et un axe
fig, ax = plt.subplots(figsize=(12, 12))

# Définir les limites de l'axe et le titre
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
ax.set_title("Diagramme de Séquence pour l'Utilisateur", fontsize=16)

# Fonction pour ajouter des lifelines avec le texte en haut
def add_lifeline(x, y_start, y_end, label, color, lw=2):
    ax.plot([x, x], [y_start, y_end], color=color, lw=lw)
    ax.text(x, y_end + 2, label, fontsize=12, ha='center', va='bottom', bbox=dict(boxstyle="round,pad=0.3", fc="white", ec=color))

# Fonction pour ajouter des messages
def add_message(x_start, x_end, y, message, direction='->'):
    if direction == '->':
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="->", lw=1.5, color='blue'),
                    fontsize=10, ha='center', va='center', color='blue')
    else:
        ax.annotate(message, xy=(x_end, y), xytext=(x_start, y),
                    arrowprops=dict(arrowstyle="<-", lw=1.5, color='green'),
                    fontsize=10, ha='center', va='center', color='green')

# Ajouter des lifelines avec plus d'espace
add_lifeline(10, 10, 90, 'Utilisateur', 'red', lw=1)
add_lifeline(50, 10, 90, 'Système', 'grey', lw=1)
add_lifeline(90, 10, 90, 'Base de Données', 'green', lw=1)

# Ajouter des messages avec plus d'espacement
y_pos = 80
step = 10

# Voir les Poubelles
add_message(10, 50, y_pos, 'Voir les Poubelles')
y_pos -= step
add_message(50, 90, y_pos, 'Récupérer Données Poubelles')
y_pos -= step
add_message(90, 50, y_pos, 'Données Poubelles', direction='<-')

# Voir Carte
y_pos -= step
add_message(10, 50, y_pos, 'Voir Carte')
y_pos -= step
add_message(50, 90, y_pos, 'Afficher Carte')
y_pos -= step
add_message(90, 50, y_pos, 'Carte Affichée', direction='<-')

# Masquer les axes
ax.axis('off')

# Afficher le diagramme
plt.show()
